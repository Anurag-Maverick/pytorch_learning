# %%
import torch

# %%
x = torch.tensor(1.0)
y = torch.tensor(2.0)

weights = torch.randn(1, requires_grad=True)

#forward pass
y_hat = x*weights
loss = (y-y_hat)**2
print(loss)

#backward pass
loss.backward()
print(weights.grad)
# Out:
# tensor([3.7052], grad_fn=<PowBackward0>)
# tensor([-3.8498])
